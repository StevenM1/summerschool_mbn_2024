# %% [markdown]
# # Part 3. Extracting signal from a region of interest
#
# In Part 1, we preprocessed the data (or, at least, explored *how* you could go about preprocessing your data). Let's just use the `fmriprep`-preprocessed data for the remainder of the tutorial. Here, we will extract signal from a region of interest: striatum. Striatum is part of the Basal Ganglia, and has repeatedly been implicated in response caution adjustments (e.g., [Forstmann et al 2008](http://www.pnas.org/content/105/45/17538/#F2); [Van Maanen et al 2011](http://www.jneurosci.org/content/31/48/17488)). In Part 3 and 4 of this tutorial, we'll see if we can replicate this result.
#
# In order to extract signal from a region of interest, we need a mask that tells us where this ROI lies in the brain. Since `fmriprep` registered ('normalized') our data to MNI152-space, we can use a mask from an atlas in MNI152-space.

# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib
from nipype.interfaces import fsl
import nilearn.datasets

# %matplotlib inline

# %% [markdown]
# ## A look at masks

# %% [markdown]
# In the directory `/data/masks/` you can find various masks, including one for the left and one for the right striatum

# %%
# !ls /data/masks/MNI152-2mm
# Out:
# GPe_L.nii.gz  GPi_L.nii.gz  STR_L.nii.gz
# GPe_R.nii.gz  GPi_R.nii.gz  STR_R.nii.gz

# %% [markdown]
# Let's load a mask and see what it looks like.

# %%
str_l = nib.load('/data/masks/MNI152-2mm/STR_L.nii.gz').get_fdata()
plt.imshow(str_l[:, 68, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# Note that this is a *probabilistic* map. The colors in the above plot indicate the *probability* for each voxel that is is part of any given individual's left striatum. Further, probabilities of 0 lead to a black pixel in the plot above.

# %% [markdown]
# Let's mask all voxels that have a probability of 50% or less of belonging to any of the striatal parts. This way, they won't end up as black pixels when we plot them, but become transparant

# %%
str_l = np.ma.masked_less(str_l, 0.5)

# %% [markdown]
# Now, `str_l` is a 3D-matrix indicating for each voxel the probability that it belongs to the left striatum. What does this look like?

# %%
plt.imshow(str_l[:, 68, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# The background is now white instead of black, which doesn't help much. But now we can superimpose this mask on an MNI152 template

# %%
# Load the MNI template
mni = nib.load('/data/mni_icbm152_nlin_asym_09c/2mm_T1.nii.gz').get_fdata()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(mni[:, 68, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[:, 68, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(132)
plt.imshow(mni[38, :, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[38, :, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(133)
plt.imshow(mni[:, :, 40].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[:, :, 40].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

# %% [markdown]
# And that's where left striatum is located probabilistically

# %% [markdown]
# Note that the `str_l` variable is a kind of image. You can apply image processing tools to it; for example, to find the center of mass (this is how the slices plotting above were chosen)

# %%
import scipy as sp
from scipy import ndimage
com = ndimage.center_of_mass(str_l)
com
# Out:
# (38.03372758952017, 68.37898108274199, 40.79747377169487)

# %% [markdown]
# 1) Can you make the same plots for right striatum? Find the center of mass, and plot it on an MNI152-brain

# %%
str_r = nib.load('/data/masks/MNI152-2mm/STR_R.nii.gz').get_fdata()
str_r = np.ma.masked_less(str_r, 0.5)
com = ndimage.center_of_mass(str_r)

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(mni[:, int(com[1]), :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[:, int(com[1]), :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(132)
plt.imshow(mni[int(com[0]), :, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[int(com[0]), :, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(133)
plt.imshow(mni[:, :, int(com[2])].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[:, :, int(com[2])].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

# %% [markdown]
# ## Extracting signal from a masked region
# Back to Nipype. Nipype contains interfaces that allows you to extract a time series *meaned* over a region of interest. The interface is called `ImageMeants()`. Let's first see how this works

# %%
# We'll need these libraries below
from nipype.interfaces import fsl
import nipype.pipeline.engine as pe
import nipype.interfaces.io as nio

# %%
# !ls /data/deriv/fmriprep/sub-483/func
# Out:
# sub-483_task-SAT_run-1_desc-confounds_regressors.json
# sub-483_task-SAT_run-1_desc-confounds_regressors.tsv
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_boldref.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-aparcaseg_dseg.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-aseg_dseg.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-brain_mask.json
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.json
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# sub-483_task-SAT_run-2_desc-confounds_regressors.json
# sub-483_task-SAT_run-2_desc-confounds_regressors.tsv
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_boldref.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-aparcaseg_dseg.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-aseg_dseg.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-brain_mask.json
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.json
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz

# %%
extracter = fsl.ImageMeants()
extracter.inputs.in_file = '/data/deriv/fmriprep/sub-483/func/sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
extracter.inputs.mask = '/data/masks/MNI152-epi/STR_L.nii.gz'

# %%
r = extracter.run()
r.outputs
# Out:
# out_file = /home/neuro/model_based_fmri/sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt

# %% [markdown]
# Now, using `np.loadtxt(<path_to_txt_file>)`, you can load the output.
#
# 2) Can you plot the data?

# %%
raw_str_data = np.loadtxt(r.outputs.out_file)   # here we load
plt.plot(raw_str_data) # plot

# %% [markdown]
# ## Making a pipeline
# Now we semi-manually extracted a single subject's time series signal meaned over striatum. We could do this in the same way for all subjects, but it's much more efficient to make a pipeline. Let's make one that extracts the time series meaned over striatum for all participants. First, set-up the nodes we want to use

# %%
# This is the node that extracts signal
extracter = pe.MapNode(fsl.ImageMeants(), iterfield='in_file', name='extract_mean_ts')

# %% [markdown]
# Note that this is a [MapNode](https://pythonhosted.org/nipype/api/generated/nipype.pipeline.engine.nodes.html#mapnode) rather than a regular Node; i.e., a Node the receives a list of inputs and applies the same interface to each element of the list.
#
# 3) In the cell below, create/fill:
# - the template for where to find the masks
# - the template for where to find the functional data (similar to Part 1)
# - all subject ids at selector.iterator.
# - fill in the mask names at selector.iterator

# %%
# Here, we set-up a SelectFile-Node
templates = {
    'mask': '/data/masks/MNI152-epi/{mask}.nii.gz',  # NB: use folder "MNI152-epi" here instead of "MNI152-2mm"
    'func': '/data/deriv/fmriprep/sub-{subject_id}/func/sub-{subject_id}_task-SAT_run-*_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
}

selector = pe.Node(nio.SelectFiles(templates=templates), name='file_selector')
selector.iterables = [('subject_id', ['197', '372', '381', '471', '483', '498', '523', '544', '548', '549', '551', '552', '553', '554', '555', '558', '559']), 
                      ('mask', ['STR_L', 'STR_R'])]


# A datasink is useful for exporting. Remember the base_directory - this is where the data will be saved later
ds = pe.Node(nio.DataSink(base_directory='/data/extracted_signals'), 
             name='datasink')

# %% [markdown]
# Then, combine everything in a Workflow.
#
# 4) In the cell below, make the right connections in the workflow: you want to connect the `selector` to the `extractor` in two ways. Remember that you can call `fsl.ImageMeants.help()` to see the input argument names

# %%
workflow = pe.Workflow(base_dir='/data/workflow_folders/', 
                       name='extract_striatum_signal')

# Connect the Nodes
workflow.connect(selector, 'mask', extracter, 'mask')
workflow.connect(selector, 'func', extracter, 'in_file')
workflow.connect(extracter, 'out_file', ds, 'extracted_timeseries')

# Make a graph to visualize what we did..
workflow.write_graph('graph.dot', format='png')
from IPython.display import Image
Image('/data/workflow_folders/extract_striatum_signal/graph.png')
# Out:
# 240725-08:57:16,778 nipype.workflow INFO:
# 	 Generated workflow graph: /data/workflow_folders/extract_striatum_signal/graph.png (graph2use=hierarchical, simple_form=True).

# %% [markdown]
# And we're ready to run

# %%
workflow.run('MultiProc', plugin_args={'n_proc': 3})
# Out:
# 240725-08:57:16,855 nipype.workflow INFO:
# 	 Workflow extract_striatum_signal settings: ['check', 'execution', 'logging', 'monitoring']
# 240725-08:57:16,974 nipype.workflow INFO:
# 	 Running in parallel.
# 240725-08:57:16,978 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.
# 240725-08:57:17,170 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/file_selector".
# 240725-08:57:17,171 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/file_selector".
# 240725-08:57:17,171 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/file_selector".
# 240725-08:57:17,173 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/file_selector".
# 240725-08:57:17,173 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/file_selector".
# 240725-08:57:17,173 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/file_selector".
# 240725-08:57:17,173 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/file_selector".
# 240725-08:57:17,174 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,175 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/file_selector".
# 240725-08:57:17,175 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_523/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_544/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/file_selector".
# 240725-08:57:17,177 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_544/file_selector".
# 240725-08:57:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_523/file_selector".
# 240725-08:57:17,177 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_548/file_selector".
# 240725-08:57:17,177 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_548/file_selector".
# 240725-08:57:17,177 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_549/file_selector".
# 240725-08:57:17,177 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_549/file_selector".
# 240725-08:57:17,178 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_551/file_selector".
# 240725-08:57:17,179 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001179s.
# 240725-08:57:17,179 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_552/file_selector".
# 240725-08:57:17,179 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_551/file_selector".
# 240725-08:57:17,180 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001482s.
# 240725-08:57:17,179 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_552/file_selector".
# 240725-08:57:17,182 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001142s.
# 240725-08:57:17,193 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,193 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,193 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,194 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,195 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001078s.
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,197 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001068s.
# 240725-08:57:17,197 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:17,198 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001095s.
# 240725-08:57:17,197 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001042s.
# 240725-08:57:17,199 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001122s.
# 240725-08:57:17,197 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001101s.
# 240725-08:57:17,199 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001423s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001357s.
# 240725-08:57:17,197 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001207s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001133s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001383s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001223s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001358s.
# 240725-08:57:17,237 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001382s.
# 240725-08:57:17,236 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001215s.
# 240725-08:57:17,196 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001216s.
# 240725-08:57:17,237 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001116s.
# 240725-08:57:17,237 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001333s.
# 240725-08:57:17,237 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001036s.
# 240725-08:57:17,238 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001056s.
# 240725-08:57:17,238 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001112s.
# 240725-08:57:18,980 nipype.workflow INFO:
# 	 [Job 0] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,983 nipype.workflow INFO:
# 	 [Job 1] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,983 nipype.workflow INFO:
# 	 [Job 2] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,984 nipype.workflow INFO:
# 	 [Job 3] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,985 nipype.workflow INFO:
# 	 [Job 4] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,986 nipype.workflow INFO:
# 	 [Job 5] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,987 nipype.workflow INFO:
# 	 [Job 6] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,988 nipype.workflow INFO:
# 	 [Job 7] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,988 nipype.workflow INFO:
# 	 [Job 8] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,989 nipype.workflow INFO:
# 	 [Job 9] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,990 nipype.workflow INFO:
# 	 [Job 10] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,991 nipype.workflow INFO:
# 	 [Job 11] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,991 nipype.workflow INFO:
# 	 [Job 12] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,992 nipype.workflow INFO:
# 	 [Job 13] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,993 nipype.workflow INFO:
# 	 [Job 14] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,995 nipype.workflow INFO:
# 	 [Job 15] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,996 nipype.workflow INFO:
# 	 [Job 16] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,996 nipype.workflow INFO:
# 	 [Job 17] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,997 nipype.workflow INFO:
# 	 [Job 18] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,998 nipype.workflow INFO:
# 	 [Job 19] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,999 nipype.workflow INFO:
# 	 [Job 20] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:18,999 nipype.workflow INFO:
# 	 [Job 21] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:19,0 nipype.workflow INFO:
# 	 [Job 22] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:19,1 nipype.workflow INFO:
# 	 [Job 23] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:19,2 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.
# 240725-08:57:19,100 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_553/file_selector".
# 240725-08:57:19,100 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_553/file_selector".
# 240725-08:57:19,100 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_554/file_selector".
# 240725-08:57:19,102 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_554/file_selector".
# 240725-08:57:19,102 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/file_selector".
# 240725-08:57:19,102 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/file_selector".
# 240725-08:57:19,103 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/file_selector".
# 240725-08:57:19,103 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/file_selector".
# 240725-08:57:19,104 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/file_selector".
# 240725-08:57:19,105 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/file_selector".
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,120 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,121 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,121 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,121 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,121 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 240725-08:57:19,122 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000582s.
# 240725-08:57:19,122 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.00063s.
# 240725-08:57:19,122 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000595s.
# 240725-08:57:19,122 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000615s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000794s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000578s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000582s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000585s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000593s.
# 240725-08:57:19,123 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.000666s.
# 240725-08:57:20,982 nipype.workflow INFO:
# 	 [Job 24] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,983 nipype.workflow INFO:
# 	 [Job 25] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,983 nipype.workflow INFO:
# 	 [Job 26] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,984 nipype.workflow INFO:
# 	 [Job 27] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,985 nipype.workflow INFO:
# 	 [Job 28] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,986 nipype.workflow INFO:
# 	 [Job 29] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,986 nipype.workflow INFO:
# 	 [Job 30] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,987 nipype.workflow INFO:
# 	 [Job 31] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,988 nipype.workflow INFO:
# 	 [Job 32] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,988 nipype.workflow INFO:
# 	 [Job 33] Completed (extract_striatum_signal.file_selector).
# 240725-08:57:20,989 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 58 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.
# 240725-08:57:21,87 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,87 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,87 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,89 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,89 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,90 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,90 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,90 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,91 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,91 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,93 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,93 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,93 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,94 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,95 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,95 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,97 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,97 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,98 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,98 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,100 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,106 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,107 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,108 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,108 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,109 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,110 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,114 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,114 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,115 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,115 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,116 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,116 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,117 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,116 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,117 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,117 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,118 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,119 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,119 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:21,119 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,119 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,119 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,117 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:21,121 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,123 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:21,123 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:22,983 nipype.workflow INFO:
# 	 [MultiProc] Running 24 tasks, and 44 jobs ready. Free memory (GB): 448.35/453.15, Free processors: 0/24.
#                      Currently running:
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
# 240725-08:57:23,878 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 2.756962s.
# 240725-08:57:23,899 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 2.779346s.
# 240725-08:57:24,984 nipype.workflow INFO:
# 	 [Job 118] Completed (_extract_mean_ts0).
# 240725-08:57:24,985 nipype.workflow INFO:
# 	 [Job 120] Completed (_extract_mean_ts0).
# 240725-08:57:24,987 nipype.workflow INFO:
# 	 [MultiProc] Running 22 tasks, and 44 jobs ready. Free memory (GB): 448.75/453.15, Free processors: 2/24.
#                      Currently running:
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts1
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
# 240725-08:57:25,74 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_523/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:25,77 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:25,70 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_523/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:25,91 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:25,772 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.674027s.
# 240725-08:57:25,772 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.650698s.
# 240725-08:57:25,775 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.65177s.
# 240725-08:57:25,759 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.65686s.
# 240725-08:57:25,786 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.664977s.
# 240725-08:57:25,796 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.699215s.
# 240725-08:57:25,808 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.7144s.
# 240725-08:57:25,901 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.809593s.
# 240725-08:57:25,911 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.791171s.
# 240725-08:57:25,918 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.827213s.
# 240725-08:57:25,974 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.864606s.
# 240725-08:57:25,988 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.889175s.
# 240725-08:57:26,30 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.911677s.
# 240725-08:57:26,31 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.920636s.
# 240725-08:57:26,89 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.991891s.
# 240725-08:57:26,101 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.974397s.
# 240725-08:57:26,101 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.989384s.
# 240725-08:57:26,101 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.982732s.
# 240725-08:57:26,103 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.976445s.
# 240725-08:57:26,112 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 5.01311s.
# 240725-08:57:26,148 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 5.055621s.
# 240725-08:57:26,240 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 5.148723s.
# 240725-08:57:26,986 nipype.workflow INFO:
# 	 [Job 102] Completed (_extract_mean_ts0).
# 240725-08:57:26,987 nipype.workflow INFO:
# 	 [Job 103] Completed (_extract_mean_ts1).
# 240725-08:57:26,988 nipype.workflow INFO:
# 	 [Job 104] Completed (_extract_mean_ts0).
# 240725-08:57:26,989 nipype.workflow INFO:
# 	 [Job 105] Completed (_extract_mean_ts1).
# 240725-08:57:26,989 nipype.workflow INFO:
# 	 [Job 106] Completed (_extract_mean_ts0).
# 240725-08:57:26,990 nipype.workflow INFO:
# 	 [Job 107] Completed (_extract_mean_ts1).
# 240725-08:57:26,990 nipype.workflow INFO:
# 	 [Job 108] Completed (_extract_mean_ts0).
# 240725-08:57:26,991 nipype.workflow INFO:
# 	 [Job 109] Completed (_extract_mean_ts1).
# 240725-08:57:26,991 nipype.workflow INFO:
# 	 [Job 110] Completed (_extract_mean_ts0).
# 240725-08:57:26,992 nipype.workflow INFO:
# 	 [Job 111] Completed (_extract_mean_ts1).
# 240725-08:57:26,993 nipype.workflow INFO:
# 	 [Job 112] Completed (_extract_mean_ts0).
# 240725-08:57:26,993 nipype.workflow INFO:
# 	 [Job 113] Completed (_extract_mean_ts1).
# 240725-08:57:26,994 nipype.workflow INFO:
# 	 [Job 114] Completed (_extract_mean_ts0).
# 240725-08:57:26,994 nipype.workflow INFO:
# 	 [Job 115] Completed (_extract_mean_ts1).
# 240725-08:57:26,995 nipype.workflow INFO:
# 	 [Job 116] Completed (_extract_mean_ts0).
# 240725-08:57:26,995 nipype.workflow INFO:
# 	 [Job 117] Completed (_extract_mean_ts1).
# 240725-08:57:26,996 nipype.workflow INFO:
# 	 [Job 119] Completed (_extract_mean_ts1).
# 240725-08:57:26,996 nipype.workflow INFO:
# 	 [Job 121] Completed (_extract_mean_ts1).
# 240725-08:57:26,997 nipype.workflow INFO:
# 	 [Job 122] Completed (_extract_mean_ts0).
# 240725-08:57:26,997 nipype.workflow INFO:
# 	 [Job 123] Completed (_extract_mean_ts1).
# 240725-08:57:26,998 nipype.workflow INFO:
# 	 [Job 124] Completed (_extract_mean_ts0).
# 240725-08:57:26,998 nipype.workflow INFO:
# 	 [Job 125] Completed (_extract_mean_ts1).
# 240725-08:57:27,0 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 54 jobs ready. Free memory (GB): 452.75/453.15, Free processors: 22/24.
#                      Currently running:
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
# 240725-08:57:27,70 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,72 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,72 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,73 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,73 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,74 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,74 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,75 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,74 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,74 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,75 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,76 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,76 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,76 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,76 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,77 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,77 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,77 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,78 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,78 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,78 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,78 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,78 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,79 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,80 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,80 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,80 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,81 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,81 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,82 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,82 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,83 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,83 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,83 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,83 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,84 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,84 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,86 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,86 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,86 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,86 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,87 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,88 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,88 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,89 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,89 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,90 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,91 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,91 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,93 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,94 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_523/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,96 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,96 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,97 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,97 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,98 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,97 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,98 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,98 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,99 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_523/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,99 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,100 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,100 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:27,100 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,100 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,100 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:27,101 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_544/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,101 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,101 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,102 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,102 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_544/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,102 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,103 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:27,103 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,103 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,104 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:27,104 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,106 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_544/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,107 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_544/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,108 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,109 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,111 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_548/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,111 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_548/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:27,111 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_548/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,113 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,113 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,113 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts0" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,118 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_548/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:27,120 nipype.workflow INFO:
# 	 [Node] Executing "_extract_mean_ts1" <nipype.interfaces.fsl.utils.ImageMeants>
# 240725-08:57:27,976 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 2.897976s.
# 240725-08:57:27,990 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 2.897016s.
# 240725-08:57:28,988 nipype.workflow INFO:
# 	 [Job 126] Completed (_extract_mean_ts0).
# 240725-08:57:28,989 nipype.workflow INFO:
# 	 [Job 127] Completed (_extract_mean_ts1).
# 240725-08:57:28,990 nipype.workflow INFO:
# 	 [Job 34] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,991 nipype.workflow INFO:
# 	 [Job 35] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,992 nipype.workflow INFO:
# 	 [Job 36] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,992 nipype.workflow INFO:
# 	 [Job 37] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,993 nipype.workflow INFO:
# 	 [Job 38] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,994 nipype.workflow INFO:
# 	 [Job 39] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,995 nipype.workflow INFO:
# 	 [Job 40] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,996 nipype.workflow INFO:
# 	 [Job 41] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,997 nipype.workflow INFO:
# 	 [Job 42] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:28,998 nipype.workflow INFO:
# 	 [Job 43] Completed (extract_striatum_signal.extract_mean_ts).
# ...
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 3.8104240000000003s.
# 240725-08:57:38,976 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 3.86698s.
# 240725-08:57:39,0 nipype.workflow INFO:
# 	 [Job 166] Completed (_extract_mean_ts0).
# 240725-08:57:39,1 nipype.workflow INFO:
# 	 [Job 167] Completed (_extract_mean_ts1).
# 240725-08:57:39,2 nipype.workflow INFO:
# 	 [Job 54] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,3 nipype.workflow INFO:
# 	 [Job 55] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,4 nipype.workflow INFO:
# 	 [Job 56] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,5 nipype.workflow INFO:
# 	 [Job 57] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,6 nipype.workflow INFO:
# 	 [Job 58] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,7 nipype.workflow INFO:
# 	 [Job 59] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,8 nipype.workflow INFO:
# 	 [Job 61] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:39,8 nipype.workflow INFO:
# 	 [Job 86] Completed (extract_striatum_signal.datasink).
# 240725-08:57:39,9 nipype.workflow INFO:
# 	 [Job 87] Completed (extract_striatum_signal.datasink).
# 240725-08:57:39,10 nipype.workflow INFO:
# 	 [Job 94] Completed (extract_striatum_signal.datasink).
# 240725-08:57:39,12 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 8 jobs ready. Free memory (GB): 451.15/453.15, Free processors: 14/24.
#                      Currently running:
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
#                        * _extract_mean_ts1
#                        * _extract_mean_ts0
# 240725-08:57:39,83 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_551/datasink".
# 240725-08:57:39,88 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,84 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_551/datasink".
# 240725-08:57:39,84 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_552/datasink".
# 240725-08:57:39,85 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_552/datasink".
# 240725-08:57:39,86 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_553/datasink".
# 240725-08:57:39,86 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:39,87 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,87 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_553/datasink".
# 240725-08:57:39,88 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,88 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:39,88 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_554/datasink".
# 240725-08:57:39,89 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:39,89 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001419s.
# 240725-08:57:39,90 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:39,91 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001902s.
# 240725-08:57:39,91 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:39,92 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00187s.
# 240725-08:57:39,92 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:39,104 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,104 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,104 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,105 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:39,107 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001447s.
# 240725-08:57:39,135 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.028462s.
# 240725-08:57:39,135 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.028739s.
# 240725-08:57:39,135 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.028767s.
# 240725-08:57:39,166 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.073516s.
# 240725-08:57:39,173 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.074263s.
# 240725-08:57:39,190 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.085672s.
# 240725-08:57:39,201 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.100169s.
# 240725-08:57:39,227 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.123598s.
# 240725-08:57:39,228 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 4.121481s.
# 240725-08:57:39,341 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.249861s.
# 240725-08:57:39,403 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 4.307779s.
# 240725-08:57:39,867 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts1", elapsed time 2.767487s.
# 240725-08:57:39,901 nipype.workflow INFO:
# 	 [Node] Finished "_extract_mean_ts0", elapsed time 2.8016199999999998s.
# 240725-08:57:41,3 nipype.workflow INFO:
# 	 [Job 158] Completed (_extract_mean_ts0).
# 240725-08:57:41,4 nipype.workflow INFO:
# 	 [Job 159] Completed (_extract_mean_ts1).
# 240725-08:57:41,5 nipype.workflow INFO:
# 	 [Job 160] Completed (_extract_mean_ts0).
# 240725-08:57:41,5 nipype.workflow INFO:
# 	 [Job 161] Completed (_extract_mean_ts1).
# 240725-08:57:41,6 nipype.workflow INFO:
# 	 [Job 162] Completed (_extract_mean_ts0).
# 240725-08:57:41,7 nipype.workflow INFO:
# 	 [Job 163] Completed (_extract_mean_ts1).
# 240725-08:57:41,7 nipype.workflow INFO:
# 	 [Job 164] Completed (_extract_mean_ts0).
# 240725-08:57:41,8 nipype.workflow INFO:
# 	 [Job 165] Completed (_extract_mean_ts1).
# 240725-08:57:41,8 nipype.workflow INFO:
# 	 [Job 168] Completed (_extract_mean_ts0).
# 240725-08:57:41,9 nipype.workflow INFO:
# 	 [Job 169] Completed (_extract_mean_ts1).
# 240725-08:57:41,9 nipype.workflow INFO:
# 	 [Job 66] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:41,10 nipype.workflow INFO:
# 	 [Job 88] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,11 nipype.workflow INFO:
# 	 [Job 89] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,12 nipype.workflow INFO:
# 	 [Job 90] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,13 nipype.workflow INFO:
# 	 [Job 91] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,14 nipype.workflow INFO:
# 	 [Job 92] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,14 nipype.workflow INFO:
# 	 [Job 93] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,15 nipype.workflow INFO:
# 	 [Job 95] Completed (extract_striatum_signal.datasink).
# 240725-08:57:41,16 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.
# 240725-08:57:41,87 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:41,96 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:41,89 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:41,89 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:41,90 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:41,91 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:41,91 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:41,91 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:41,91 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:41,92 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:41,93 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:41,93 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:41,93 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:41,94 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:41,94 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:41,94 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:41,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:41,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:41,96 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:41,97 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:41,97 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:41,98 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:41,98 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/datasink".
# 240725-08:57:41,99 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:41,100 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:41,100 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts0" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/extract_mean_ts/mapflow/_extract_mean_ts0".
# 240725-08:57:41,101 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:41,102 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts0" - collecting precomputed outputs
# 240725-08:57:41,102 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts0" found cached.
# 240725-08:57:41,104 nipype.workflow INFO:
# 	 [Node] Setting-up "_extract_mean_ts1" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/extract_mean_ts/mapflow/_extract_mean_ts1".
# 240725-08:57:41,105 nipype.workflow INFO:
# 	 [Node] Cached "_extract_mean_ts1" - collecting precomputed outputs
# 240725-08:57:41,105 nipype.workflow INFO:
# 	 [Node] "_extract_mean_ts1" found cached.
# 240725-08:57:41,124 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.021052s.
# 240725-08:57:43,5 nipype.workflow INFO:
# 	 [Job 62] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:43,7 nipype.workflow INFO:
# 	 [Job 63] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:43,8 nipype.workflow INFO:
# 	 [Job 64] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:43,9 nipype.workflow INFO:
# 	 [Job 65] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:43,10 nipype.workflow INFO:
# 	 [Job 67] Completed (extract_striatum_signal.extract_mean_ts).
# 240725-08:57:43,10 nipype.workflow INFO:
# 	 [Job 100] Completed (extract_striatum_signal.datasink).
# 240725-08:57:43,12 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.
# 240725-08:57:43,90 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/datasink".
# 240725-08:57:43,90 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/datasink".
# 240725-08:57:43,92 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/datasink".
# 240725-08:57:43,93 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/datasink".
# 240725-08:57:43,93 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:43,93 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:43,94 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/datasink".
# 240725-08:57:43,95 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:43,96 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00164s.
# 240725-08:57:43,97 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:43,97 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240725-08:57:43,97 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001115s.
# 240725-08:57:43,98 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001537s.
# 240725-08:57:43,119 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.021234s.
# 240725-08:57:43,124 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.02644s.
# 240725-08:57:45,7 nipype.workflow INFO:
# 	 [Job 96] Completed (extract_striatum_signal.datasink).
# 240725-08:57:45,8 nipype.workflow INFO:
# 	 [Job 97] Completed (extract_striatum_signal.datasink).
# 240725-08:57:45,9 nipype.workflow INFO:
# 	 [Job 98] Completed (extract_striatum_signal.datasink).
# 240725-08:57:45,9 nipype.workflow INFO:
# 	 [Job 99] Completed (extract_striatum_signal.datasink).
# 240725-08:57:45,10 nipype.workflow INFO:
# 	 [Job 101] Completed (extract_striatum_signal.datasink).
# 240725-08:57:45,11 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 24/24.

# %% [markdown]
# 5) Again, visualize what the output data structure looks like using `!tree`

# %%
# !tree /data/extracted_signals
# Out:
# /data/extracted_signals
# └── extracted_timeseries
#     ├── _mask_STR_L_subject_id_197
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-197_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-197_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_372
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-372_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-372_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_381
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-381_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-381_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_471
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-471_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-471_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_483
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_498
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-498_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-498_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_523
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-523_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-523_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_544
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-544_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-544_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_548
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-548_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-548_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_549
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-549_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-549_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_551
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-551_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-551_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_552
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-552_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-552_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_553
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-553_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-553_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_554
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-554_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-554_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_555
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-555_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-555_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_558
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-558_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-558_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_559
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-559_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-559_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_197
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-197_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-197_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_372
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-372_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-372_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_381
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-381_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-381_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_471
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-471_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-471_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_483
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_498
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-498_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-498_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_523
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-523_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-523_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_544
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-544_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-544_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_548
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-548_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-548_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_549
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-549_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-549_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_551
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-551_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-551_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_552
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-552_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-552_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_553
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-553_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-553_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_554
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-554_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-554_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_555
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-555_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-555_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_558
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-558_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-558_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     └── _mask_STR_R_subject_id_559
#         ├── _extract_mean_ts0
#         │   └── sub-559_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#         └── _extract_mean_ts1
#             └── sub-559_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#
# 103 directories, 68 files
